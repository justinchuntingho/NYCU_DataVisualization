# %% [markdown]
# # Challenge 1
#
# So here's a recap of last week.
#
# Below, you have a list that contains the social media platforms that I used throughout the day. First have a look at the data:

# %%
visits = ['Instagram',
            'Instagram',
            'Facebook App',
            'Instagram',
            'Facebook App',
            'Facebook Web',
            'Instagram',
            'Gmail',
            'Instagram',
            'Facebook App',
            'Instagram',
            'Threads',
            'Instagram',
            'Facebook App',
            'Facebook App',
            'Gmail',
            'Instagram',
            'Instagram',
            'Facebook Web',
            'Facebook App',
            'Instagram',
            'Threads',
            'Instagram',
            'Gmail',
            'Facebook App',
            'Instagram',
            'Instagram',
            'Facebook App',
            'Facebook Web',
            'Instagram',
            'Gmail',
            'Instagram',
            'Threads',
            'Facebook App',
            'Instagram',
            'Instagram',
            'Facebook App',
            'Gmail',
            'Facebook Web',
            'Instagram',
            'Facebook App',
            'Instagram',
            'Threads',
            'Instagram',
            'Facebook App',
            'Gmail',
            'Instagram',
            'Instagram',
            'Facebook Web',
            'Facebook App',
            'Instagram',
            'Threads',
            'Gmail',
            'Instagram',
            'Facebook App',
            'Instagram',
            'Facebook Web',
            'Instagram',
            'Gmail',
            'Threads',
            'Facebook App',
            'Instagram',
            'Instagram',
            'Facebook App',
            'Gmail',
            'Instagram',
            'Facebook Web',
            'Instagram',
            'Threads',
            'Facebook App',
            'Instagram',
            'Gmail',
            'Instagram',
            'Facebook App',
            'Facebook Web',
            'Facebook App',
            'Instagram',
            'Threads',
            'Gmail',
            'Facebook App',
            'Instagram',
            'Instagram',
            'Facebook Web',
            'Facebook App',
            'Gmail',
            'Threads',
            'Instagram',
            'Facebook App',
            'Instagram',
            'Instagram',
            'Facebook Web',
            'Gmail',
            'Facebook App',
            'Threads',
            'Instagram',
            'Instagram',
            'Facebook App',
            'Gmail',
            'Facebook Web',
            'Instagram']

# %% [markdown]
# Now, answer the following questions (not by hand, of course, but by writing appropriate code). For each question, provide the necessary code. Note that there are more than one possible way to tackle this.
#
# ### 1.1 Oops..
# - I messed up with the data, Gmail is not even a social media. Create another list that does not contain "Gmail"
# - How long is the final list?
#
# ### 1.2 Which Platform was used the most?
# - Count the occurence of each platform
# - You may have realized that probably some of the categories should have been merged. Is there a way to count both "Facebook App" and Facebook Web" in one go?
# - This definitely have multiple ways to tackle
# - Here are some techniques that you may find useful for this:
# ```
# # slicing
# # for example:
# somestring[:5]      # to get the  the first five characters
# somelist[-1]        # to get the last element of a list
#
# # the "in" operator:
# somesearchstring in somestring   # returns True if found, False if not
# ```

# %% [markdown]
# # Challenge 2
#
# The json file `books.json` contains ratings of books. The json file is structured as follows: keys are titles of books and values the rating given to them on a scale from 1-10.
#
# * Read the json file into a dictionary.
#
# * Create a list of book titles that only contains books rated above average (keeping only the names).
#
# * Write that list into a text file (.txt).

# %% [markdown]
# # Challenge 3
#
# Let's get to the final boss of the week. Remember the YouBike data?
#
# - Which station has the highest average usage?
#
# PS: Working with real world data is VERY difficult, don't feel bad if you cannot do it this week, I will show you some other ways to do it in the future...

# %%
import json
with open('jan_data.json', mode = "r", encoding='utf-8') as json_file:
    data = json.load(json_file)

# %% [markdown]
# #### Pro Tips
# When dealing with task like this, it is highly recommend to first write codes that can deal with ONE item. And then use the codes for all items using a loop. Let's try to find the average of one day. To do so, you need to break down the task into smaller subtasks:
#
# - Select the entries with keys that named "日期__日使用筆數", one way to to is to write a loop and keep only entries that belong to this format, and then write another loop to loop through it
# - Convert the vales into integers `int()`
# - Calculate the average, remember `sum()` and `len()`?

# %%
datum = data[0]
datum
# Out:
# {'縣市別代碼': '10018',
#  '機關代碼': '376580000A',
#  '所屬年月': '202601',
#  '場站編號': '500401001',
#  '場站名稱': '北新竹火車站(新竹高工)',
#  '日期1日使用筆數': '96',
#  '日期2日使用筆數': '110',
#  '日期3日使用筆數': '124',
#  '日期4日使用筆數': '110',
#  '日期5日使用筆數': '175',
#  '日期6日使用筆數': '164',
#  '日期7日使用筆數': '154',
#  '日期8日使用筆數': '138',
#  '日期9日使用筆數': '168',
#  '日期10日使用筆數': '106',
#  '日期11日使用筆數': '103',
#  '日期12日使用筆數': '164',
#  '日期13日使用筆數': '156',
#  '日期14日使用筆數': '171',
#  '日期15日使用筆數': '175',
#  '日期16日使用筆數': '191',
#  '日期17日使用筆數': '131',
#  '日期18日使用筆數': '116',
#  '日期19日使用筆數': '164',
#  '日期20日使用筆數': '174',
#  '日期21日使用筆數': '147',
#  '日期22日使用筆數': '142',
#  '日期23日使用筆數': '178',
#  '日期24日使用筆數': '142',
#  '日期25日使用筆數': '135',
#  '日期26日使用筆數': '145',
#  '日期27日使用筆數': '125',
#  '日期28日使用筆數': '154',
#  '日期29日使用筆數': '213',
#  '日期30日使用筆數': '178',
#  '日期31日使用筆數': '106'}

# %% [markdown]
# ### If you think this is too easy...
#
# Try to find:
# - Which day from which station has the highest usage of all?
#
# Tips: You start by creating dummy variables, and update them if you find a station with higher value.

# %%
max_avg = -999
max_station = None
